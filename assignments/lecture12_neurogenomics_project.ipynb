# %% [markdown]
# # Lecture 12: Single-Cell Neurogenomics Project
#
# **Date:** January 10, 2026 | **Time:** 60 minutes
#
# ## Learning Objectives
# - Apply complete scRNA-seq workflow to brain data
# - Perform QC, clustering, and annotation of brain cell types
# - Identify brain-specific marker genes
# - Interpret biological findings
#
# ---
#
# ## Project Overview
#
# You will analyze a mouse brain single-cell dataset, identifying major brain cell types and their markers.
#
# ---
#
# ## Setup

# %%
import scanpy as sc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi=100, frameon=False, figsize=(8, 8))

# %% [markdown]
# ## Task 1: Data Loading and QC (20 points)
#
# ### Instructions
# 1. Load mouse brain dataset (Allen Institute or similar)
# 2. Calculate QC metrics
# 3. Filter low-quality cells
# 4. Document your QC decisions

# %%
# TODO: Load and QC brain data
# Use: sc.datasets.paul15() as example or load Allen Brain data

# %% [markdown]
# ## Task 2: Preprocessing and Dimensionality Reduction (20 points)
#
# ### Instructions
# 1. Normalize and log-transform
# 2. Identify highly variable genes
# 3. Perform PCA and determine optimal PCs
# 4. Compute UMAP embedding

# %%
# TODO: Preprocess data

# %% [markdown]
# ## Task 3: Clustering and Cell Type Identification (30 points)
#
# ### Instructions
# 1. Perform Leiden clustering
# 2. Identify marker genes for each cluster
# 3. Annotate brain cell types:
#    - Neurons (Snap25, Rbfox3)
#    - Astrocytes (Gfap, Aqp4)
#    - Oligodendrocytes (Mog, Mbp)
#    - Microglia (Cx3cr1, P2ry12)
#    - OPCs (Pdgfra, Cspg4)
# 4. Visualize cell types on UMAP

# %%
# TODO: Cluster and annotate

# %% [markdown]
# ## Task 4: Neuronal Subtype Analysis (20 points)
#
# ### Instructions
# 1. Subset neuronal clusters
# 2. Re-cluster to identify subtypes:
#    - Excitatory (Slc17a7)
#    - Inhibitory (Gad1, Gad2)
#    - Dopaminergic (Th)
# 3. Find subtype-specific markers
# 4. Visualize neuronal diversity

# %%
# TODO: Analyze neuronal subtypes

# %% [markdown]
# ## Task 5: Biological Interpretation (10 points)
#
# ### Instructions
# 1. Compare cell type proportions
# 2. Identify cell-type-specific biological processes
# 3. Discuss potential disease relevance
# 4. Suggest future analyses
#
# **Your Analysis:**
#
# [Write your biological interpretation here]
