# %% [markdown]
# # Lecture 9: Spatial Analysis and Spatial Structure
#
# **Date:** January 2, 2026 | **Time:** 60 minutes
#
# ## Learning Objectives
# - Process and analyze spatial transcriptomics data using squidpy
# - Compute spatial statistics and neighborhood enrichment
# - Identify spatially variable genes
# - Characterize spatial niches
#
# ---
#
# ## Setup

# %%
import scanpy as sc
import squidpy as sq
import numpy as np

sc.settings.verbosity = 3

# %% [markdown]
# ## Task 1: Loading Spatial Data (20 points)
#
# ### Instructions
# 1. Load Visium mouse brain dataset: `sq.datasets.visium_hne_adata()`
# 2. Visualize spatial coordinates
# 3. Show gene expression in spatial context
# 4. Plot total counts in tissue

# %%
# TODO: Load and visualize spatial data

# %% [markdown]
# ## Task 2: Spatial Neighborhood Analysis (30 points)
#
# ### Instructions
# 1. Build spatial graph using `sq.gr.spatial_neighbors`
# 2. Perform clustering on spatial data
# 3. Compute neighborhood enrichment
# 4. Visualize which cell types are spatially co-localized

# %%
# TODO: Analyze spatial neighborhoods

# %% [markdown]
# ## Task 3: Spatially Variable Genes (30 points)
#
# ### Instructions
# 1. Identify spatially variable genes using Moran's I
# 2. Visualize top SVGs in tissue
# 3. Compare with highly variable genes
# 4. Interpret biological meaning

# %%
# TODO: Find spatially variable genes

# %% [markdown]
# ## Task 4: Spatial Niches (20 points)
#
# ### Instructions
# 1. Define spatial niches based on expression
# 2. Identify niche-specific markers
# 3. Visualize niches in tissue
# 4. Compare with anatomical structures

# %%
# TODO: Characterize spatial niches
