# %% [markdown]
# # Lecture 8: Ligand-Receptor Interactions and Differential Abundance
#
# **Date:** December 27, 2025 | **Time:** 60 minutes
#
# ## Learning Objectives
# - Analyze cell-cell communication with liana
# - Identify significant ligand-receptor pairs
# - Visualize interaction networks
# - Perform differential abundance analysis
#
# ---
#
# ## Setup

# %%
import scanpy as sc
import liana as li
import numpy as np

li.mt.show_resources()

# %% [markdown]
# ## Task 1: Cell-Cell Communication Analysis (35 points)
#
# ### Instructions
# 1. Load PBMC 3k dataset with cell type annotations
# 2. Run liana with consensus method
# 3. Filter significant interactions (magnitude > 0.5)
# 4. Visualize interaction heatmap

# %%
# TODO: Analyze cell-cell communication

# %% [markdown]
# ## Task 2: Ligand-Receptor Networks (30 points)
#
# ### Instructions
# 1. Identify top ligand-receptor pairs
# 2. Focus on T cell-monocyte interactions
# 3. Create dot plot of top interactions
# 4. Visualize network graph

# %%
# TODO: Visualize LR networks

# %% [markdown]
# ## Task 3: Differential Abundance Testing (35 points)
#
# ### Instructions
# 1. Compare cell type proportions between two conditions
# 2. Use statistical test (e.g., chi-square)
# 3. Visualize composition differences
# 4. Identify significantly changed populations

# %%
# TODO: Perform differential abundance analysis
