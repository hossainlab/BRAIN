# %% [markdown]
# # Lecture 10: Deep Learning in Single-Cell Genomics - Part 1
#
# **Date:** January 3, 2026 | **Time:** 60 minutes
#
# ## Learning Objectives
# - Understand fundamentals of deep learning for single-cell
# - Explore VAE architectures (scVI)
# - Train scVI model for dimensionality reduction
# - Extract and visualize latent representations
#
# ---
#
# ## Setup

# %%
import scanpy as sc
import scvi
import numpy as np
import matplotlib.pyplot as plt

scvi.settings.verbosity = 3

# %% [markdown]
# ## Task 1: Preparing Data for scVI (20 points)
#
# ### Instructions
# 1. Load PBMC 10k dataset
# 2. Perform basic QC filtering
# 3. Setup AnnData for scVI
# 4. Register the AnnData object

# %%
# TODO: Prepare data for scVI

# %% [markdown]
# ## Task 2: Training scVI Model (30 points)
#
# ### Instructions
# 1. Create scVI model with appropriate parameters
# 2. Train the model (max_epochs=400)
# 3. Plot training history (ELBO loss)
# 4. Check model convergence

# %%
# TODO: Train scVI model

# %% [markdown]
# ## Task 3: Latent Representation Analysis (30 points)
#
# ### Instructions
# 1. Extract latent representation
# 2. Compute UMAP on latent space
# 3. Compare with PCA-based UMAP
# 4. Perform clustering on latent space

# %%
# TODO: Analyze latent representation

# %% [markdown]
# ## Task 4: Denoised Expression (20 points)
#
# ### Instructions
# 1. Get denoised gene expression from scVI
# 2. Compare raw vs denoised for marker genes
# 3. Visualize both on UMAP
# 4. Discuss advantages of denoising

# %%
# TODO: Compare raw vs denoised expression
