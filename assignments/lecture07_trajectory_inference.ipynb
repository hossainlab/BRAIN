# %% [markdown]
# # Lecture 7: Trajectory Inference and Fate Probability
#
# **Date:** December 26, 2025 | **Time:** 60 minutes
#
# ## Learning Objectives
# - Learn trajectory inference methods using scVelo and CellRank
# - Apply RNA velocity analysis
# - Visualize developmental trajectories
# - Infer cell fate probabilities
#
# ---
#
# ## Setup

# %%
import scanpy as sc
import scvelo as scv
import cellrank as cr
import numpy as np

scv.settings.verbosity = 3
scv.settings.set_figure_params('scvelo')

# %% [markdown]
# ## Task 1: RNA Velocity Analysis (30 points)
#
# ### Instructions
# 1. Load pancreas development dataset: `scv.datasets.pancreas()`
# 2. Preprocess and compute moments
# 3. Estimate RNA velocity using dynamical model
# 4. Visualize velocity streams on UMAP

# %%
# TODO: Perform RNA velocity analysis

# %% [markdown]
# ## Task 2: Identifying Driver Genes (20 points)
#
# ### Instructions
# 1. Identify top velocity genes
# 2. Plot velocity for specific genes
# 3. Interpret which genes drive differentiation

# %%
# TODO: Identify and visualize driver genes

# %% [markdown]
# ## Task 3: Trajectory Analysis with CellRank (30 points)
#
# ### Instructions
# 1. Compute velocity kernel
# 2. Identify initial and terminal states
# 3. Compute fate probabilities
# 4. Visualize cell fates on UMAP

# %%
# TODO: Perform CellRank analysis

# %% [markdown]
# ## Task 4: Lineage Drivers (20 points)
#
# ### Instructions
# 1. Identify genes that drive specific lineages
# 2. Plot gene expression trends along pseudotime
# 3. Visualize lineage-specific markers

# %%
# TODO: Identify lineage drivers
